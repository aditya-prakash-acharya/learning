# %% [markdown]
# #variables in python

# %%
a = 1 #integer
print(a)

b = 1.357101 #decimal number
print(b)

c = "madhav" #word dentence use quotes
print(c)

Aditya = 26 #declare a variable using variable
d = Aditya
print(d)

x = 10 #adding number to a variable
print(x+1)

p,q,r =  10,20,30  #assign multiple variables
print(p,q,r)
# Out:
# 1
# 1.357101
# madhav
# 26
# 11
# 10 20 30

# %% [markdown]
# # MyName = "Aditya"  #pascal case
# # myName = "Aditya"  #camel case
# # myname = "Aditya"  #flat case
# # my_name = "Aditya"  #snake case

# %%
# Rules to declare the variable
# 1.Variable name mustr start with Letter or _
_My_Name = "Aditya"
print("_My_Name")

# Variable names can contain: Letter ,Number, Underscore(_)
my_name1 = "aditya"
r1 = 26
_1 = 1

#Variables are case sensitive
myname = "RisabhMishra"
print(myName)

# Variables names cant be reserved word
# for = 10  which the word for is reserved in python
# Out:
# _My_Name
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 13
#       9 _1 = 1
#      10
#      11 #Variables are case sensitive
#      12 myname = "RisabhMishra"
# ---> 13 print(myName)
#
# NameError: name 'myName' is not defined
