# %%
# data types in python 
a = 1
b = 1
print(a)
print(a+b)
print(type(a)) #types checking
# Out:
# 1
# 2
# <class 'int'>

# %%
c = "1"
d = "1" #not a number its a string 
print(c+d) 
print(type(c)) #type casting
# Out:
# 11
# <class 'str'>

# %%
#basic data types in python 
#############1. Numeric ###########
a1 = 1  #integer
a2 = 1.5 #float
print(type(a2))

a3 = complex(3,5) #complex
print(type(a3))

##########2. Sequence ############
b1 = "Madhav" #string
b11 = '26'
print(type(b1))

b2 = [1,4,7,26,108,'aditya'] #list
print(type(b2))

b3 = (1,4,7,26,108,'aditya') #tuple
print(type(b3))

#########3. Dictionary ############
my_dictionary = {'name': 'Aditya', 'age' : '24', 'city' : 'Thane'}
print(type(my_dictionary))

##########4. Sets###############
my_sets = {1,4,7,26,108,'aditya'}
print(type(my_sets))

##########5. Boolean ################
bool1 = True
bool2 = False
print(type(bool1))

########6. Binary###########
# bytes , bytearray, memoryview
byte1 = b"aditya"
print(type(byte1))
# Out:
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>
# <class 'bool'>
# <class 'bytes'>
