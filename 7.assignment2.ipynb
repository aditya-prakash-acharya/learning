# %%
#q1. take name 3 subjects markls and pribt name and perentage 

student_name = input("enter your name")
english_marks = input("enter your marks")
maths_marks = input("enter your marks")
science_marks = input("enter your marks")

#percentage
percentage = ((int(english_marks)+int(maths_marks)+int(science_marks))/300 *100)
print(f"Hello {student_name} your percentage is {percentage}")
# Out:
# Hello aditya your percentage is 80.0

# %%
student_name = input("enter your name")
english_marks = int(input("enter your marks"))
maths_marks = int(input("enter your marks"))
science_marks = int(input("enter your marks"))

#percentage
percentage = ((english_marks+maths_marks+science_marks)/300 *100)
print(f"Hello {student_name} your percentage is {percentage}")
# Out:
# Hello aditya your percentage is 80.0

# %%
#take input name age height student store in dictionary and printas output

#dictionary
user_data = {}

#input data
user_data['name'] = input("enter your name: ")
user_data['age'] = int(input("enter your age: "))
user_data['height'] = float(input("enter your height: "))
user_data['student'] = input("enter your status yes/no: ")

#print output
print(user_data)
# Out:
# {'name': 'Aditya', 'age': 24, 'height': 5.4, 'student': 'no'}
