# %% [markdown]
# input function is usd to take input from user

# %% [markdown]
# # #it reads the input as a string and return it

# %%
#imput function in python

a = input()
print(a)
# Out:
# k

# %%
a = input()
print(int(a)+int(a))
# Out:
# 4

# %%
# Prompting the user for their name
name = input("Enter your name: ")
# Displaying the user's input
print("Hello, " + name + "!")
# Out:
# Hello, 2!

# %%
#adding two numbers

num1 = input("enter the first number: ")
num2 = input("enter the second number: ")
sum = (num1+num2)
print("the sum of the numbers are ", sum)
#i added 2 + 5 but it returned as a string  because all the input values are string we need to convert it into a integer
# Out:
# the sum of the numbers are  25

# %%
#a fix


num1 = input("enter the first number: ")
num2 = input("enter the second number: ")
num1 = int(num1)
num2 = int(num2)
sum = (num1+num2)
print("the sum of the numbers are ", sum)
# Out:
# the sum of the numbers are  54

# %%
#same code of above different try
num1 = input("enter your first number")
num2 = input("enter your second number")
print(f"sum of {num1} and {num2} is {int(num1)+int(num2)}")
# Out:
# sum of 5 and 6 is 11

# %%
name = input("enter your name ")
print(f"hello {name} welcomne to my course")
# Out:
# hello adi welcomne to my course

# %%
age = input("enter your age")
print(f"hello you are {age} and next year your age will be {int(age)+1} ")
# Out:
# hello you are 25 and next year your age will be 26

# %%
#hw write a program to input student name and marks
#print name and percentage

name = input("enter your name: ")
marks = input("enter your marks out of 500")
print(f"hello {name} out of 500 you got {marks} so your percentage is {int(marks)/500*100}")
# Out:
# hello Aditya out of 500 you got 400 so your percentage is 80.0
