# %% [markdown]
# condtional statement allows you to execute codebased on cndition evaluaes to true or false. they are essentials for controlling the flow of a program and making decisions based on different input conditions

# %%
#example 
a = 26
b = 108
if b > a:
    print("b is greater than a ")

#no output for this  because a is greater
a = 269
b = 108
if b > a:
    print("b is greater than a ")
# Out:
# b is greater than a

# %% [markdown]
# 'if' Condition Statement

# %%
#the if statement is only used to execyte the block of code 
# only when the condition is true
#syntax
   #if condition:
# THE CODE EXECUTES ONLY WHEN THE CONDITION IS TRUE

#EXAMPLE
age = 26 
if age > 19:
  print("you are adult")

age = int(input("enter your age"))
if age > 19:
    print(f"you are an adult you are {age}")
# Out:
# you are adult
# you are an adult you are 25

# %% [markdown]
# 'if-else' Condition Statement

# %%
#if-else statement provides an alternative 
# block of code to executeif the condition is false
#Syantax 
temperature = 30
if temperature > 25:
    print("its a hot day")
else:
    print("its a cool day")

#2
age = int(input("enter your age"))
if age > 19:
    print(f"you are an adult you are {age}")
else:
    print(f"you are not an adult ypu are just {age}")
# Out:
# its a hot day
# you are not an adult ypu are just 6

# %% [markdown]
# 'if-elif-else' Conditioal Statement

# %%
#The if-elif-else allows to check multiple conditions 
# and execute diffeent blocks of code based on which condition is true
#Syantax
#if condition1 :
#   print(code to execute if the condition1 is true)
#elif condition2 :
#   print(code to execute if the condition2 is true)
#else:
#   print(code executes if non of the above is true)

# %%
#if-elif-else statement
#multiple conditons

marks = int(input("Enter Your Marks"))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
else:
    print("Grade D")
# Out:
# Grade B

# %% [markdown]
# Nested 'if-else' Conditional Statement

# %%
#A nested if-else statement in Python involves placing an if-else statement 
#inside another if-else statement. This allows for more complex 
# decision-making by checking multiple conditions that depend on each other.

#Syntax: 
#if condition1: 
    # Code block for condition1 being True 
#    if condition2: 
        # Code block for condition2 being True 
#    else: 
        # Code block for condition2 being False 
#else: 
    # Code block for condition1 being False

# %%
# Nested if-else statement
# if-else inside if-else statement
# multile conditions depend on each other

#Number Classification: Let's say you want to classify a number as positive, 
# negative, or zero and further classify positive numbers as even or odd.

number = int(input("Enter a Number"))

if number > 0: # checking positive number
    if number % 2 == 0:
        print("this is an even number")
    else:
        print("this is odd number")
else:
    if number == 0:
     print("this is zero")
    else:
       print("this is a negative number")
# Out:
# this is a negative number

# %% [markdown]
# Conditional Expressions (ternary operator)

# %%
# Syntax: 
# value_if_true if condition else value_if_false 

age = 16
status = "adult" if age >= 18 else "minor"
print(status)

marks = int(input("Enter your marks"))
result = "pass" if marks >= 35 else "fail"
print(result)
# Out:
# minor
# pass

# %% [markdown]
# H/W

# %%
# what is the expected output and reason
value = None
if value:
    print("Value is True")
else:
    print("Value is False")

# Python mein "Truthiness" kya hoti hai?
# Jab hum if value: likhte hain, toh Python value ko check karta hai ki woh "sach" (True) hai ya "jhoot" (False).

# Python mein kuch values hain jo automatically False maani jaati hain (inhe Falsy kehte hain):

# None (Jaise aapke paas hai)
# False
# 0 (Zero)
# 0.0 (Zero decimal)
# "" (Khali string)
# [] (Khali list)
# {} (Khali dictionary)
# Agar value inmein se koi bhi hai, toh if value: ka condition False maana jata hai aur code else block mein chala jaata hai.
# Out:
# Value is False

# %% [markdown]
# write a simple program to determine if a given year is a leap
# year using user input.

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2016 is a leap year.

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    is_leap = True
elif year % 100 == 0:
    is_leap = False
elif year % 4 == 0:
    is_leap = True
else:
    is_leap = False

if is_leap:
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2026 is not a leap year.
