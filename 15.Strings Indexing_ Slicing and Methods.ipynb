# %%
# String Indexing

# we can access individual characters in string using index.
# it uses 0 based indexing which means it starts with 0

# index: position of a character

# syntax: string[Index_value]
# String Indexing

my_name = "ADITYA"
# index:   012345

print(my_name[0])       # first character of str 
print(my_name[1])       # second character of str 
print(my_name[2])       # third character of str 
print(my_name[3])       # fourth character of str 
print(my_name[4])       # fifth character of str 
print(my_name[5])       # sixth character of str 
print(my_name[-1])      # negative charactr of str
print(my_name[-4])      # negative charactr of str
# Out:
# A
# D
# I
# T
# Y
# A
# A
# I

# %%
name2   =  "Hello World"
# index:    012345678910
# -ve index:1110987654321 -
print(name2[5])     # blank space is also a char
print(name2[-1])    # last char from str
print(name2[-3])    # 3rd last char from str 
print(name2[-11])   # 1st last char from str
# Out:
#
# d
# r
# H

# %%
# String Slicing  
# helps to accesing parts of sequence
# slicing hlps to get subset of characters using string specified ranges of indices.

# syntax: string[start : end : step]

my_name = "ADITYA"
# index:   012345 

print(my_name[0:3])     # default step = 1
print(my_name[0:3:1]) 

print(my_name[0:5:1]) 

print(my_name[3:5:1]) 

print(my_name[0:5:2])   # step = 2

print(my_name[0:5:3])   # step = 3

print(my_name[0:5:4])   # step = 4 

print(my_name[0:2])        # first 2 chars
print(my_name[0:3])        # first 3 chars
print(my_name[2:5])        # third to fifth chars
print(my_name[1:4])        # second to fourth chars
print(my_name[-1:])        # last char of str
print(my_name[5:])         # last char of str
print(my_name[-2:])        # last 2 char of str
print(my_name[-3:])        # last 3 char of str
print(my_name[0::2])       # every second char
print(my_name[:])          # all char
print(my_name[::])         # all char 
print(my_name[::-1])       # reverse the string
# Out:
# ADI
# ADI
# ADITY
# TY
# AIY
# AT
# AY
# AD
# ADI
# ITY
# DIT
# A
# A
# YA
# TYA
# AIY
# ADITYA
# ADITYA
# AYTIDA

# %%
# String Methods

word = "Hello, Aditya" 

#1. len()
print(len(word)) 

#2. upper()
print(word.upper())

#3. lower()
print(word.lower())

#4. count()
print(word.count('A')) 
print(word.count('a')) 

#5. find()
print(word.find('e'))

#6. Split()
print(word.split(','))
print(word.split()) 

#7. Replace()
print(word.replace("Aditya", "Subham")) 

#8. title()
print(word.title()) 

#9. strip()
word2 = "  Hello World   "
print(len(word2))
print(word2.strip()) 

#10. join()
zwords = ("Aditya", "is", "Great")
print(" ".join(zwords))
print("-".join(zwords))
# Out:
# 13
# HELLO, ADITYA
# hello, aditya
# 1
# 1
# 1
# ['Hello', ' Aditya']
# ['Hello,', 'Aditya']
# Hello, Subham
# Hello, Aditya
# 16
# Hello World
# Madhav is Great
# Madhav-is-Great
