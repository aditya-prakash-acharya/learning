# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # #this is how we comment in python using  '#'

# %% [markdown]
# # * variable is something where we can store values

# %%
a = 5
print(a)
# Out:
# 5

# %%
instructor = 'aditya acharya'
print("hello your instructor is ", instructor, sep="- ")#seperator is sep
# Out:
# hello your instructor is - aditya acharya

# %% [markdown]
# anything written inside inside the "" ''  ''' ''' is called as string like print('aditya")

# %%
print("5+3")
print(5+3)
# Out:
# 5+3
# 8

# %%
b = 4
c = 6
print(b+c)
print(b*c)
print(b/c)
# Out:
# 10
# 24
# 0.6666666666666666
