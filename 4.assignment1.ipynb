# %% [markdown]
# Q.No 1. write a python program that prints t6he following texts as it is

# %% [markdown]
# python is fun

# %% [markdown]
# "quotes" and 'single quotes' can be tricky

# %%
#answer
a = "python is fun"
print(a)

b = '''"quotes" and 'single quotes' can be tricky'''
print(b)
print("\"quotes\" and 'single quotes' can be tricky")
# Out:
# python is fun
# "quotes" and 'single quotes' can be tricky
# "quotes" and 'single quotes' can be tricky

# %% [markdown]
# Q.No 2.For a business create 3 variables to store_name, age, and city. Then print a sentence that uses these variables.

# %%
store_name = "welcome"
age = 2
city = "thane"
print("hello from", store_name, "stores. we are", age,"years old in the city of", city)
print(f"hello from {store_name} stores.we are {age} years old in the city of {city}")
# Out:
# hello from welcome stores. we are 2 years old in the city of thane
# hello from welcome stores.we are 2 years old in the city of thane
